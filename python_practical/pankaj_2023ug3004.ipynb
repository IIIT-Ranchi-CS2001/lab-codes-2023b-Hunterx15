# %%
import pandas as pd
import numpy as np
data=pd.read_csv("/Users/pankajjangid/Downloads/python_practical/AQI_Data.csv")
print("the first 8 rows is:")
#the first eight rows
print(data.head(8))
print("the last 5 rows is:")
#the last five rows
print(data.tail())
# showing dtype 
print("the dtype of each column is:")
print(data.dtypes)
# showing number of non null values
print("the number of non-null values in each column is:")
print(data.count())
# mean of aqi
print("the mean of aqi:")
c=[data.loc[:,'AQI']]
print(np.mean(c))
# max of pm2.5
print("the max of pm2.5:")

d=[data.loc[:,'PM2.5']]
print(np.max(d))
# min of pm10
print("the min of pm10")
e=[data.loc[:,'PM10']]
print(np.min(e))
print("common program end:")

# set 1 A PART
city_counts = data['City'].value_counts().to_dict()
print(city_counts)

# set 1 b part
try:
    data['Total_Pollutant'] = np.sum(data[['PM2.5', 'PM10', 'NO2', 'CO', 'O3', 'SO2']], axis=1)
    data.to_csv('pollutant.csv', mode='a', header=False, index=False)
except FileNotFoundError:
    data['Total_Pollutant'] = np.sum(data[['PM2.5', 'PM10', 'NO2', 'CO', 'O3', 'SO2']], axis=1)
    data.to_csv('pollutant.csv', mode='w', header=True, index=False)
except PermissionError:
    print("Permission denied to write to the file.")
except Exception as e:
    print("An error occurred: ", str(e))
# Out:
# the first 8 rows is:
#     City        Date  AQI  PM2.5  PM10        NO2        CO          O3  \
# 0  Delhi  2024-01-01  152    153   151  26.509131  1.581413  123.401530
# 1  Delhi  2024-01-02  264    288   268  87.955853  1.242119  144.533790
# 2  Delhi  2024-01-03  307    344   357  94.469744  0.101480  198.520196
# 3  Delhi  2024-01-04  363    334   347  12.075618  1.097072   85.973585
# 4  Delhi  2024-01-05  237    266   250  51.046299  1.591834   47.938019
# 5  Delhi  2024-01-06  369    321   327  64.679037  0.423996   22.359803
# 6  Delhi  2024-01-07  365    328   347  44.687485  0.130336   53.869827
# 7  Delhi  2024-01-08  493    513   526  54.565922  0.165338  182.770876
#
#          SO2
# 0  25.062474
# 1   5.926302
# 2  32.786668
# 3   7.099955
# 4  28.140550
# 5  47.699849
# 6  15.846146
# 7  16.645099
# the last 5 rows is:
#       City        Date  AQI  PM2.5  PM10        NO2        CO          O3  \
# ...
